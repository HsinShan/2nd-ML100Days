# %% [markdown]
# ## HW1
# 我選擇的資料為 Competitions 中的 LANL Earthquake Prediction
#
# 1.我認為這組資料對於世界很有貢獻，因為地震若能預測到何時會發生，就能及早避難，減少傷亡人數及損失
#
# 2.資料的提供者來自PennState，是由 Chas Bolton, Jacques Riviere, Paul Johnson and Prof. Chris Marone的實驗而來的
#
# 3.資料型態為為結構化資料
#
# 4.使用mean absolute error來評估預測出來的時間和下個地震發生之間的時間差

# %% [markdown]
# ## HW2
#
# 1.我將「提升業績」定義為營收增加，所以若要提升業績最直接的方式就是要提高載客率，因此若可以預測該時段哪個地區的載客率較高，就可以派更多的車前往該地區等候，因此我認為核心問題為「找出特定時段何地的載客率是較高的?」
#
# 2.由交通部統計的相關交通及計程車營運報告，加上Crowdsourcing
#
# 3.結構化資料，因為所需資料像是特定時間、地點、taxi招呼數等資料多為數值類型
#
# 4.驗證多個時段，預測出的最高載客率地區和實際的最高載客率地區的載客率是否差距很大

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,yp):
    """
    請完成這個 Function 後往下執行
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 12.918

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 263.431
# The Mean absolute error is 12.918
